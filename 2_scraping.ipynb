# %%
import os
from dotenv import load_dotenv
from firecrawl import FirecrawlApp

# 1. Load the hidden variables from the .env file
load_dotenv()

# 2. Safely grab the API key
# os.getenv will look into the loaded .env file and pull the value matching the name
my_key = os.getenv("FIRECRAWL_API_KEY")

# 3. Initialize Firecrawl with the secured key
app = FirecrawlApp(api_key=my_key)


# 4. Run your scrape!
result = app.scrape(
    'https://valmikiramayan.net/',
    formats=['markdown']
)

print(result.markdown)
# Out:
# c:\Users\shivc\OneDrive - Indian Institute of Technology Bombay\Desktop\DDKGGS\myenv\Lib\site-packages\firecrawl\v2\types.py:988: UserWarning: Field name "json" in "MonitorPageDiff" shadows an attribute in parent "BaseModel"
#   class MonitorPageDiff(BaseModel):
# c:\Users\shivc\OneDrive - Indian Institute of Technology Bombay\Desktop\DDKGGS\myenv\Lib\site-packages\firecrawl\v2\types.py:1003: UserWarning: Field name "json" in "MonitorPageSnapshot" shadows an attribute in parent "BaseModel"
#   class MonitorPageSnapshot(BaseModel):
# Contents
#
# |     |     |     |     |     |     |
# | --- | --- | --- | --- | --- | --- |
# | [![Bala Kanda](https://valmikiramayan.net/bala.gif)](https://valmikiramayan.net/utf8/baala/baala_contents.htm) | [![Ayodhya Kanda](https://valmikiramayan.net/ayodhya.gif)](https://valmikiramayan.net/utf8/ayodhya/ayodhya_contents.htm) | [![Aranya Kanda](https://valmikiramayan.net/aranya.gif)](https://valmikiramayan.net/utf8/aranya/aranya_contents.htm) | [![Kishkindha Kanda](https://valmikiramayan.net/kish.gif)](https://valmikiramayan.net/utf8/kish/kishkindha_contents.htm) | [![Sundara Kanda](https://valmikiramayan.net/sundara.gif)](https://valmikiramayan.net/utf8/sundara/sundara_contents.htm) | [![Yuddha Kanda](https://valmikiramayan.net/yuddha.gif)](https://valmikiramayan.net/utf8/yuddha/yuddha_contents.htm) |
#
# |     |     |     |     |     |     |
# | --- | --- | --- | --- | --- | --- |
# | [**Home**\<br>**Page**](https://valmikiramayan.net/index.html) | **[Ramayana in a painting](https://valmikiramayan.net/BapuPic.htm)** | **[Ramayana Resources](https://valmikiramayan.net/resources.htm)** | **[Your Comments here](https://valmikiramayan.net/feedback.html)** | **[Comments thus far](https://valmikiramayan.net/comments.html)** | **[Useful \**<br>**Links](https://valmikiramayan.net/misc.htm)** |
#
# <body bgcolor="#FFFFFF" text="#000000" link="#0000FF" vlink="#800080">
# <!\-\- Piwik -->
# <script type="text/javascript">
# var \_paq = \_paq \|\| \[\];
# \_paq.push(\['trackPageView'\]);
# \_paq.push(\['enableLinkTracking'\]);
# (function() {
# var u="//edthebe.com/piwik/";
# \_paq.push(\['setTrackerUrl', u+'piwik.php'\]);
# \_paq.push(\['setSiteId', 1\]);
# var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')\[0\];
# g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
# })();
# </script>
# <noscript><p><img src="//edthebe.com/piwik/piwik.php?idsite=1" style="border:0;" alt="" /></p></noscript>
# <!\-\- End Piwik Code -->
# <p>This page contains frames. You need a Web browser that supports frames to view this page. </p>
# </body>

# %%
import os
from dotenv import load_dotenv
from firecrawl import FirecrawlApp

# 1. Load the hidden variables
load_dotenv()

# 2. Grab the API key
my_key = os.getenv("FIRECRAWL_API_KEY")

# 3. Initialize Firecrawl
app = FirecrawlApp(api_key=my_key)

# 4. Target a DIRECT page, bypassing the frameset
target_url = 'http://www.valmikiramayan.net/bala_1.htm'

print(f"Scraping {target_url}...")

result = app.scrape_url(
    target_url,
    formats=['markdown']
)

# Print the first 1000 characters just to verify it worked!
print(result.markdown[:1000])
# Out:
# Scraping http://www.valmikiramayan.net/bala_1.htm...
# [Verse\\
# Locator](http://www.valmikiramayan.net/bala_1.htm#VerseLocator)
#
# ![](http://www.valmikiramayan.net/Img20.gif)
#
# ### **Book I : Bala Kanda - The Youth**
#
# Chapter \[ Sarga \] 1
#
# Introduction
#
# Divine sage Narada arrives at the hermitage of sage Välmiki in
# order to enlighten him and keep him informed of his duty to author the
# epic poem Ramayana. In the dialogue between these two sages, Valmiki solicits
# from Narada about most virtuous person on earth, Rama. Narada while eulogizing
# Rama, gives an outline of Ramayana, truly highlighting those aspects that
# are keynotes in this epic, like virtuosity, generosity, morality, chastity
# and the like. Here starts the first verse in bala kanda:
#
# [Verse\\
# Locator](http://www.valmikiramayan.net/bala_1.htm#VerseLocator)
#
# tapaHsvaadhyaayanirataM tapasvii vaagvidaaM
# varam \|naaradaM paripaprachchha vaalmiikirmunipuN^gavam
# \|\| 1-1-1 _1\. tapasvii = sage, vaalmiiki = Valmiki, paripaprachchha= questioned,_
# _naaradam= with Narada, tapaH + svaadhyaaya +

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import json
# Assume Firecrawl and your chosen LLM library are imported here

# 1. The URLs you want to process (Issue 1 Solved)
target_urls = [
    'http://www.valmikiramayan.net/bala_1.htm',
    'http://www.valmikiramayan.net/bala_2.htm'
]

master_graph_data = []

# 2. The Extraction Prompt (The "Rules" for the LLM)
extraction_prompt = """
You are a Sanskrit Knowledge Graph extraction engine. 
Read the following markdown text containing translated Sanskrit verses.
Extract the main event into the following strict JSON schema.
Use only Paninian karaka roles for grammar (kartri, karma, adhikarana, etc.).

SCHEMA:
{
  "source_url": "string",
  "entities": [
    {"name": "string", "type": "string", "karaka_role": "string"}
  ],
  "relation": "string"
}

TEXT TO ANALYZE:
"""

# 3. The Automation Loop (Issue 2 Solved)
# 3. The Automation Loop
for url in target_urls:
    print(f"Scraping {url}...")
    
    # A. Scrape the raw text
    scraped_data = app.scrape_url(url, formats=['markdown'])
    raw_markdown = scraped_data.markdown
    
    # --- FIX: Truncate text to stay under Groq's free tier limits ---
    # 5,000 characters is roughly 1,000 - 1,200 tokens, perfectly safe!
    safe_markdown = raw_markdown[:5000] 
    # ----------------------------------------------------------------
    
    # B. Send the SAFE truncated text to the LLM
    print("Sending a safe snippet to Groq...")
    response = llm_client.invoke(extraction_prompt + safe_markdown)
    
    # C. Convert the LLM text output into a Python dictionary
    structured_json = json.loads(response.content)
    
    # D. Save it to our master list
    master_graph_data.append(structured_json)

# 4. Save the final output to a file
with open('automated_graph_data.json', 'w') as f:
    json.dump(master_graph_data, f, indent=2)

print("Extraction complete! Ready to send to Neo4j.")
# Out:
# Scraping http://www.valmikiramayan.net/bala_1.htm...
# Sending a safe snippet to Groq...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 47
#      43     # ----------------------------------------------------------------
#      44
#      45     # B. Send the SAFE truncated text to the LLM
#      46     print("Sending a safe snippet to Groq...")
# ---> 47     response = llm_client.invoke(extraction_prompt + safe_markdown)
#      48
#      49     # C. Convert the LLM text output into a Python dictionary
#      50     structured_json = json.loads(response.content)
#
# NameError: name 'llm_client' is not defined

# %%
import os
import json
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from firecrawl import FirecrawlApp

# 1. Load Environment Variables
load_dotenv(override=True)

# 2. Initialize Firecrawl
app = FirecrawlApp(api_key=os.getenv("FIRECRAWL_API_KEY"))

# 3. Initialize the Groq LLM Client (THIS IS WHAT WAS MISSING!)
llm_client = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.2, 
    api_key=os.getenv("GROQ_API_KEY")
)

# 4. The URLs you want to process
target_urls = [
    'http://www.valmikiramayan.net/bala_1.htm',
    'http://www.valmikiramayan.net/bala_2.htm'
]

master_graph_data = []

# 5. The Extraction Prompt
extraction_prompt = """
You are a Sanskrit Knowledge Graph extraction engine. 
Read the following markdown text containing translated Sanskrit verses.
Extract the main event into the following strict JSON schema.
Use only Paninian karaka roles for grammar (kartri, karma, adhikarana, etc.).

SCHEMA:
{
  "source_url": "string",
  "entities": [
    {"name": "string", "type": "string", "karaka_role": "string"}
  ],
  "relation": "string"
}

TEXT TO ANALYZE:
"""

# 6. The Automation Loop
for url in target_urls:
    print(f"Scraping {url}...")
    
    # A. Scrape the raw text (Updated to dict access for safety)
    scraped_data = app.scrape_url(url, params={'formats': ['markdown']})
    raw_markdown = scraped_data.get('markdown', '')
    
    # B. Truncate text to stay under Groq's free tier limits
    safe_markdown = raw_markdown[:5000] 
    
    # C. Send the SAFE truncated text to the LLM
    print("Sending a safe snippet to Groq...")
    response = llm_client.invoke(extraction_prompt + safe_markdown)
    
    # D. Convert the LLM text output into a Python dictionary
    # We use .strip() to clean up any hidden characters the LLM might add
    try:
        # LLMs sometimes wrap JSON in markdown code blocks like ```json ... ```
        clean_text = response.content.replace("```json", "").replace("```", "").strip()
        structured_json = json.loads(clean_text)
        master_graph_data.append(structured_json)
        print("Successfully extracted JSON!")
    except json.JSONDecodeError:
        print(f"Error parsing JSON from {url}. The LLM output was messy.")

# 7. Save the final output to a file
with open('automated_graph_data.json', 'w') as f:
    json.dump(master_graph_data, f, indent=2)

print("\nExtraction complete! Check 'automated_graph_data.json'. Ready to send to Neo4j.")
