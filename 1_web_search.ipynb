# %%
import os
from dotenv import load_dotenv
from firecrawl import FirecrawlApp

# 1. Load the hidden variables from the .env file
load_dotenv()

# 2. Safely grab the API key
# os.getenv will look into the loaded .env file and pull the value matching the name
my_key = os.getenv("FIRECRAWL_API_KEY")

# 3. Initialize Firecrawl with the secured key
app = FirecrawlApp(api_key=my_key)

# 4. Run your scrape!
result = app.search(
    'https://en.wikipedia.org/wiki/Taj_Mahal',
    formats=['markdown']
)

print(result.markdown)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      12 # 3. Initialize Firecrawl with the secured key
#      13 app = FirecrawlApp(api_key=my_key)
#      14
#      15 # 4. Run your scrape!
# ---> 16 result = app.search(
#      17     'https://en.wikipedia.org/wiki/Taj_Mahal',
#      18     formats=['markdown']
#      19 )
#
# TypeError: FirecrawlClient.search() got an unexpected keyword argument 'formats'
